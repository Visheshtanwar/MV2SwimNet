# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras import layers
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing import image_dataset_from_directory
from sklearn.model_selection import KFold
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, roc_curve, auc
import matplotlib.pyplot as plt

# Define Swin Transformer Block
class SwinTransformerBlock(layers.Layer):
    def __init__(self, dim, num_heads, window_size, ff_dim, **kwargs):
        super(SwinTransformerBlock, self).__init__(**kwargs)
        self.attention = layers.MultiHeadAttention(num_heads=num_heads, key_dim=dim)
        self.ffn = tf.keras.Sequential([
            layers.Dense(ff_dim, activation='relu'),
            layers.Dense(dim)
        ])
        self.norm1 = layers.LayerNormalization(epsilon=1e-6)
        self.norm2 = layers.LayerNormalization(epsilon=1e-6)

    def call(self, inputs):
        attn_output = self.attention(inputs, inputs)
        x = self.norm1(inputs + attn_output)
        ffn_output = self.ffn(x)
        return self.norm2(x + ffn_output)

# Define Swin Transformer Model
class SwinTransformer(layers.Layer):
    def __init__(self, embed_dim, depths, num_heads, window_size, ff_dim, **kwargs):
        super(SwinTransformer, self).__init__(**kwargs)
        self.blocks = [
            SwinTransformerBlock(
                dim=embed_dim,
                num_heads=num_heads[i],
                window_size=window_size,
                ff_dim=ff_dim
            )
            for i in range(len(depths))
        ]

    def call(self, inputs):
        x = inputs
        for block in self.blocks:
            x = block(x)
        return x

# Define Hybrid Model
class HybridModel(tf.keras.Model):
    def __init__(self, num_classes):
        super(HybridModel, self).__init__()
        self.cnn = MobileNetV2(include_top=False, input_shape=(224, 224, 3), weights="imagenet")
        self.reduce_dim = layers.Conv2D(128, kernel_size=1, padding="same")
        self.swin_transformer = SwinTransformer(
            embed_dim=128,
            depths=[2, 2, 6, 2],
            num_heads=[4, 8, 16, 32],
            window_size=7,
            ff_dim=256
        )
        self.global_pool = layers.GlobalAveragePooling2D()
        self.classifier = tf.keras.Sequential([
            layers.Dense(128, activation='relu'),
            layers.Dropout(0.5),
            layers.Dense(128, activation='relu'),
            layers.Dropout(0.4),
            layers.Dense(128, activation='relu'),
            layers.Dropout(0.3),
            layers.Dense(128, activation='relu'),
            layers.Dense(num_classes, activation='softmax')
        ])

    def call(self, inputs):
        cnn_features = self.cnn(inputs)
        reduced_features = self.reduce_dim(cnn_features)
        swin_features = self.swin_transformer(reduced_features)
        features = self.global_pool(swin_features)
        return self.classifier(features)

# Load Dataset
data_folder = "/kaggle/input/meinet-k/dataset_png"
batch_size = 32
img_size = (224, 224)

raw_dataset = image_dataset_from_directory(
    data_folder,
    image_size=img_size,
    batch_size=batch_size,
    label_mode='int',
    shuffle=True
)

class_names = raw_dataset.class_names
num_classes = len(class_names)
print(f"Class names: {class_names}")

dataset_images, dataset_labels = [], []
for image_batch, label_batch in raw_dataset.unbatch():
    dataset_images.append(image_batch.numpy())
    dataset_labels.append(label_batch.numpy())

dataset_images = np.array(dataset_images) / 255.0
dataset_labels = np.array(dataset_labels)

# Initialize and compile model
inputs = tf.keras.Input(shape=(224, 224, 3))
model = HybridModel(num_classes=num_classes)
outputs = model(inputs)
model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer=Adam(learning_rate=0.0001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# Found 3630 files belonging to 3 classes.
# Class names: ['axial', 'coronal', 'sagittal']
# Model: "functional_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ hybrid_model (HybridModel)           │ (None, 3)                   │       6,709,827 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 6,709,827 (25.60 MB)
#  Trainable params: 6,675,715 (25.47 MB)
#  Non-trainable params: 34,112 (133.25 KB)

# %%
def plot_training_history(history):
    """
    Plot training and validation accuracy and loss.
    """
    plt.figure(figsize=(14, 5))
    
    # Accuracy
    plt.subplot(1, 2, 1)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.grid()

    # Loss
    plt.subplot(1, 2, 2)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid()

    plt.show()

def plot_roc_curve(y_true, y_pred, num_classes):
    """
    Plot ROC curve for multi-class classification.
    """
    plt.figure(figsize=(10, 8))
    for i in range(num_classes):
        fpr, tpr, _ = roc_curve(y_true == i, y_pred[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, label=f'Class {i} (AUC = {roc_auc:.2f})')

    plt.plot([0, 1], [0, 1], 'k--', lw=2)
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve')
    plt.legend(loc='lower right')
    plt.grid()
    plt.show()

def plot_confusion_matrix(y_true, y_pred, class_names):
    """
    Plot confusion matrix.
    """
    cm = confusion_matrix(y_true, y_pred)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_names)
    disp.plot(cmap=plt.cm.Blues, xticks_rotation='vertical')
    plt.title("Confusion Matrix")
    plt.grid(False)
    plt.show()

def visualize_predictions(images, true_labels, pred_labels, class_names, num_samples=4):
    """
    Visualize a grid of predictions with their true and predicted labels.
    Properly rescales images for display.
    """
    num_samples = min(num_samples, len(images))
    indices = np.random.choice(len(images), num_samples, replace=False)
    grid_size = int(np.ceil(np.sqrt(num_samples)))

    plt.figure(figsize=(grid_size * 4, grid_size * 4))
    for i, idx in enumerate(indices):
        image = images[idx]
        true_label = true_labels[idx]
        pred_label = pred_labels[idx]

        # Rescale image for display (if needed)
        if image.max() <= 1.0:  # If normalized, scale back to [0, 255]
            image = (image * 255).astype("uint8")

        plt.subplot(grid_size, grid_size, i + 1)
        plt.imshow(image)
        plt.axis('off')
        plt.title(
            f"True: {class_names[true_label]}\nPred: {class_names[pred_label]}",
            color="green" if true_label == pred_label else "red"
        )

    plt.tight_layout()
    plt.show()


# K-Fold Cross-Validation Loop
kf = KFold(n_splits=3, shuffle=True, random_state=42)
fold = 1

for train_idx, val_idx in kf.split(dataset_images, dataset_labels):
    print(f"\nTraining fold {fold}...")

    # Reset model weights at the start of each fold
    model.set_weights(model.get_weights())

    train_images, val_images = dataset_images[train_idx], dataset_images[val_idx]
    train_labels, val_labels = dataset_labels[train_idx], dataset_labels[val_idx]

    train_dataset = tf.data.Dataset.from_tensor_slices((train_images, train_labels)).batch(batch_size)
    val_dataset = tf.data.Dataset.from_tensor_slices((val_images, val_labels)).batch(batch_size)

    # Callbacks
    lr_schedule = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1)
    early_stopping = EarlyStopping(monitor='val_accuracy', patience=60 , restore_best_weights=True, verbose=1)

    # Train model
    history = model.fit(
        train_dataset,
        validation_data=val_dataset,
        epochs=100,  # Use smaller epochs for quick testing
        callbacks=[ early_stopping],
        verbose=1
    )

    # Plot training history
    plot_training_history(history)

    # Evaluate model
    val_predictions = model.predict(val_dataset)
    val_pred_classes = tf.argmax(val_predictions, axis=1).numpy()

    # Classification Report
    print("\nClassification Report:")
    print(classification_report(val_labels, val_pred_classes, target_names=class_names, digits=4))

    # Visualize predictions
    visualize_predictions(val_images, val_labels, val_pred_classes, class_names, num_samples=4)

    # Plot ROC Curve
    plot_roc_curve(val_labels, val_predictions, num_classes)

    # Plot Confusion Matrix
    plot_confusion_matrix(val_labels, val_pred_classes, class_names)

    fold += 1
# Out:
# Training fold 1...
# Epoch 1/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 112s 648ms/step - accuracy: 0.6413 - loss: 0.7830 - val_accuracy: 0.9967 - val_loss: 0.0374
# Epoch 2/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - accuracy: 0.9798 - loss: 0.1111 - val_accuracy: 0.9959 - val_loss: 0.0186
# Epoch 3/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - accuracy: 0.9934 - loss: 0.0431 - val_accuracy: 0.8488 - val_loss: 0.9746
# Epoch 4/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.
100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 8.7652e-05 - val_accuracy: 0.9983 - val_loss: 0.0469
# Epoch 79/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 1.9339e-04 - val_accuracy: 0.9983 - val_loss: 0.0477
# Epoch 80/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 1.8695e-05 - val_accuracy: 0.9983 - val_loss: 0.0486
# Epoch 81/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 3.3621e-05 - val_accuracy: 0.9983 - val_loss: 0.0489
# Epoch 81: early stopping
# Restoring model weights from the end of the best epoch: 21.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 9s 130ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        axial     0.9976    1.0000    0.9988       411
#      coronal     1.0000    0.9953    0.9976       423
#     sagittal     0.9973    1.0000    0.9987       376
#
#     accuracy                         0.9983      1210
#    macro avg     0.9983    0.9984    0.9984      1210
# weighted avg     0.9984    0.9983    0.9983      1210
# Training fold 2...
# Epoch 1/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 11s 125ms/step - accuracy: 0.9678 - loss: 0.2198 - val_accuracy: 0.9967 - val_loss: 0.0177
# Epoch 2/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9964 - loss: 0.0302 - val_accuracy: 0.9950 - val_loss: 0.0252
# Epoch 3/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9943 - loss: 0.0509 - val_accuracy: 0.9926 - val_loss: 0.0564
# Epoch 4/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9967 - loss: 0.0291 - val_accuracy: 0.9669 - val_loss: 0.1331
# Epoch 5/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9992 - loss: 0.0161 - val_accuracy: 0.9959 - val_loss: 0.0261
# Epoch 6/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9983 - loss: 0.0151 - val_accuracy: 0.9967 - val_loss: 0.0217
# Epoch 7/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - accuracy: 0.9988 - loss: 0.0165 - val_accuracy: 0.9975 - val_loss: 0.0171
# Epoch 8/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9998 - loss: 0.0044 - val_accuracy: 0.9975 - val_loss: 0.0151
# Epoch 9/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9995 - loss: 0.0084 - val_accuracy: 0.9975 - val_loss: 0.0196
# Epoch 10/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - accuracy: 0.9964 - loss: 0.0390 - val_accuracy: 1.0000 - val_loss: 3.6079e-04
# Epoch 11/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - accuracy: 0.9985 - loss: 0.0062 - val_accuracy: 1.0000 - val_loss: 2.9161e-04
# Epoch 12/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 1.1258e-04
# Epoch 13/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 112ms/step - accuracy: 1.0000 - loss: 0.0011 - val_accuracy: 1.0000 - val_loss: 6.5259e-05
# Epoch 14/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0015 - val_accuracy: 1.0000 - val_loss: 3.7963e-05
# Epoch 15/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 112ms/step - accuracy: 1.0000 - loss: 6.6562e-04 - val_accuracy: 1.0000 - val_loss: 2.2774e-05
# Epoch 16/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 7.3550e-04 - val_accuracy: 1.0000 - val_loss: 1.3206e-05
# Epoch 17/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 112ms/step - accuracy: 1.0000 - loss: 5.4675e-04 - val_accuracy: 1.0000 - val_loss: 9.6016e-06
# Epoch 18/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 5.3111e-04 - val_accuracy: 1.0000 - val_loss: 6.7438e-06
# Epoch 19/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 1.0000 - loss: 7.7850e-04 - val_accuracy: 1.0000 - val_loss: 5.2182e-06
# Epoch 20/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 5.3347e-06
# Epoch 21/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 112ms/step - accuracy: 1.0000 - loss: 5.7121e-04 - val_accuracy: 1.0000 - val_loss: 3.4913e-06
# Epoch 22/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 4.4587e-04 - val_accuracy: 1.0000 - val_loss: 2.4523e-06
# Epoch 23/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 3.1952e-04 - val_accuracy: 1.0000 - val_loss: 1.9886e-06
# Epoch 24/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 2.9350e-04 - val_accuracy: 1.0000 - val_loss: 1.6011e-06
# Epoch 25/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 3.6432e-04 - val_accuracy: 1.0000 - val_loss: 1.4179e-06
# Epoch 26/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 1.3984e-04 - val_accuracy: 1.0000 - val_loss: 1.7989e-06
# Epoch 27/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 3.5642e-04 - val_accuracy: 1.0000 - val_loss: 2.5892e-06
# Epoch 28/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 2.1623e-04 - val_accuracy: 1.0000 - val_loss: 4.0801e-06
# Epoch 29/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 2.8124e-04 - val_accuracy: 1.0000 - val_loss: 2.7336e-06
# Epoch 30/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 1.4232e-04 - val_accuracy: 1.0000 - val_loss: 2.3096e-06
# Epoch 31/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 1.7531e-04 - val_accuracy: 1.0000 - val_loss: 1.2495e-06
# Epoch 32/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 1.2147e-04 - val_accuracy: 1.0000 - val_loss: 9.7895e-07
# Epoch 33/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 5.7398e-04 - val_accuracy: 1.0000 - val_loss: 7.6240e-07
# Epoch 34/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 1.9003e-04 - val_accuracy: 1.0000 - val_loss: 4.4834e-07
# Epoch 35/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 7.9025e-05 - val_accuracy: 1.0000 - val_loss: 3.3614e-07
# Epoch 36/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 3.2690e-04 - val_accuracy: 1.0000 - val_loss: 2.2531e-07
# Epoch 37/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 1.4090e-04 - val_accuracy: 1.0000 - val_loss: 2.1270e-07
# Epoch 38/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 8.3384e-05 - val_accuracy: 1.0000 - val_loss: 1.5625e-07
# Epoch 39/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 8.7566e-05 - val_accuracy: 1.0000 - val_loss: 1.3300e-07
# Epoch 40/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 2.2686e-04 - val_accuracy: 1.0000 - val_loss: 1.2029e-07
# Epoch 41/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 3.5343e-05 - val_accuracy: 1.0000 - val_loss: 1.1389e-07
# Epoch 42/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 6.8913e-05 - val_accuracy: 1.0000 - val_loss: 7.8422e-08
# Epoch 43/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 8.5705e-05 - val_accuracy: 1.0000 - val_loss: 7.7929e-08
# Epoch 44/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 7.4018e-05 - val_accuracy: 1.0000 - val_loss: 4.1674e-08
# Epoch 45/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 1.9121e-04 - val_accuracy: 1.0000 - val_loss: 3.9014e-08
# Epoch 46/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 6.8730e-05 - val_accuracy: 1.0000 - val_loss: 3.8817e-08
# Epoch 47/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 1.9865e-04 - val_accuracy: 1.0000 - val_loss: 3.8915e-08
# Epoch 48/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 6.8709e-05 - val_accuracy: 1.0000 - val_loss: 3.9112e-08
# Epoch 49/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 3.0704e-05 - val_accuracy: 1.0000 - val_loss: 3.9605e-08
# Epoch 50/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 5.7420e-05 - val_accuracy: 1.0000 - val_loss: 4.0984e-08
# Epoch 51/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - accuracy: 1.0000 - loss: 1.4287e-05 - val_accuracy: 1.0000 - val_loss: 4.8176e-08
# Epoch 52/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 2.7724e-05 - val_accuracy: 1.0000 - val_loss: 3.1624e-08
# Epoch 53/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 3.3247e-05 - val_accuracy: 1.0000 - val_loss: 3.8323e-08
# Epoch 54/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 2.5158e-05 - val_accuracy: 1.0000 - val_loss: 8.7875e-08
# Epoch 55/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 3.2924e-05 - val_accuracy: 1.0000 - val_loss: 1.7170e-07
# Epoch 56/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 1.7977e-04 - val_accuracy: 1.0000 - val_loss: 4.2796e-07
# Epoch 57/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 7.1507e-05 - val_accuracy: 1.0000 - val_loss: 9.9160e-07
# Epoch 58/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 6.5836e-05 - val_accuracy: 1.0000 - val_loss: 1.9127e-06
# Epoch 59/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 5.9724e-05 - val_accuracy: 1.0000 - val_loss: 4.4077e-06
# Epoch 60/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 1.1117e-05 - val_accuracy: 1.0000 - val_loss: 1.0427e-05
# Epoch 61/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 1.2661e-05 - val_accuracy: 1.0000 - val_loss: 1.8873e-05
# Epoch 62/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 1.4449e-05 - val_accuracy: 1.0000 - val_loss: 4.2159e-05
# Epoch 63/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 9.4364e-06 - val_accuracy: 1.0000 - val_loss: 6.9959e-05
# Epoch 64/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 3.2683e-05 - val_accuracy: 1.0000 - val_loss: 1.6438e-04
# Epoch 65/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 1.3349e-05 - val_accuracy: 1.0000 - val_loss: 4.2998e-04
# Epoch 66/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 8.0739e-06 - val_accuracy: 0.9992 - val_loss: 0.0010
# Epoch 67/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 2.7765e-05 - val_accuracy: 0.9992 - val_loss: 0.0019
# Epoch 68/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 1.0000 - loss: 1.7583e-05 - val_accuracy: 0.9992 - val_loss: 0.0026
# Epoch 69/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - accuracy: 1.0000 - loss: 1.4352e-04 - val_accuracy: 0.9992 - val_loss: 0.0036
# Epoch 70/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 1.0000 - loss: 1.3487e-05 - val_accuracy: 0.9992 - val_loss: 0.0045
# Epoch 70: early stopping
# Restoring model weights from the end of the best epoch: 10.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        axial     1.0000    1.0000    1.0000       424
#      coronal     1.0000    1.0000    1.0000       392
#     sagittal     1.0000    1.0000    1.0000       394
#
#     accuracy                         1.0000      1210
#    macro avg     1.0000    1.0000    1.0000      1210
# weighted avg     1.0000    1.0000    1.0000      1210
# Training fold 3...
# Epoch 1/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 11s 125ms/step - accuracy: 0.9967 - loss: 0.0255 - val_accuracy: 0.9884 - val_loss: 0.0634
# Epoch 2/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9637 - loss: 0.1356 - val_accuracy: 0.7017 - val_loss: 1.5727
# Epoch 3/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9909 - loss: 0.0502 - val_accuracy: 0.8554 - val_loss: 0.4299
# Epoch 4/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9968 - loss: 0.0290 - val_accuracy: 0.9512 - val_loss: 0.2340
# Epoch 5/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9929 - loss: 0.0493 - val_accuracy: 0.8256 - val_loss: 0.7510
# Epoch 6/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9946 - loss: 0.0449 - val_accuracy: 0.8934 - val_loss: 0.7038
# Epoch 7/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9962 - loss: 0.0153 - val_accuracy: 0.9438 - val_loss: 0.3679
# Epoch 8/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9987 - loss: 0.0087 - val_accuracy: 0.9843 - val_loss: 0.0533
# Epoch 9/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9876 - loss: 0.0418 - val_accuracy: 0.9868 - val_loss: 0.0469
# Epoch 10/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9892 - loss: 0.0279 - val_accuracy: 0.9942 - val_loss: 0.0284
# Epoch 11/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9963 - loss: 0.0144 - val_accuracy: 0.9934 - val_loss: 0.0317
# Epoch 12/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9967 - loss: 0.0166 - val_accuracy: 0.9934 - val_loss: 0.0295
# Epoch 13/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9969 - loss: 0.0084 - val_accuracy: 0.9934 - val_loss: 0.0305
# Epoch 14/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9975 - loss: 0.0064 - val_accuracy: 0.9942 - val_loss: 0.0267
# Epoch 15/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9963 - loss: 0.0069 - val_accuracy: 0.9711 - val_loss: 0.0983
# Epoch 16/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9934 - loss: 0.0518 - val_accuracy: 0.9331 - val_loss: 0.2057
# Epoch 17/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9981 - loss: 0.0141 - val_accuracy: 0.9322 - val_loss: 0.2030
# Epoch 18/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - accuracy: 0.9987 - loss: 0.0104 - val_accuracy: 0.9521 - val_loss: 0.1515
# Epoch 19/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9987 - loss: 0.0103 - val_accuracy: 0.9570 - val_loss: 0.1455
# Epoch 20/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9990 - loss: 0.0115 - val_accuracy: 0.9711 - val_loss: 0.0963
# Epoch 21/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9987 - loss: 0.0146 - val_accuracy: 0.9826 - val_loss: 0.0713
# Epoch 22/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9990 - loss: 0.0100 - val_accuracy: 0.9860 - val_loss: 0.0569
# Epoch 23/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9990 - loss: 0.0112 - val_accuracy: 0.9909 - val_loss: 0.0405
# Epoch 24/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9990 - loss: 0.0121 - val_accuracy: 0.9909 - val_loss: 0.0440
# Epoch 25/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - accuracy: 0.9983 - loss: 0.0134 - val_accuracy: 0.9959 - val_loss: 0.0221
# Epoch 26/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9987 - loss: 0.0099 - val_accuracy: 0.9934 - val_loss: 0.0238
# Epoch 27/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - accuracy: 0.9988 - loss: 0.0107 - val_accuracy: 0.9711 - val_loss: 0.1369
# Epoch 28/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9984 - loss: 0.0098 - val_accuracy: 0.9843 - val_loss: 0.0871
# Epoch 29/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0074 - val_accuracy: 0.9860 - val_loss: 0.0660
# Epoch 30/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0101 - val_accuracy: 0.9901 - val_loss: 0.0416
# Epoch 31/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9992 - loss: 0.0084 - val_accuracy: 0.9967 - val_loss: 0.0222
# Epoch 32/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9992 - loss: 0.0103 - val_accuracy: 0.9975 - val_loss: 0.0157
# Epoch 33/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - accuracy: 0.9992 - loss: 0.0114 - val_accuracy: 0.9992 - val_loss: 0.0062
# Epoch 34/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0069 - val_accuracy: 0.9992 - val_loss: 0.0064
# Epoch 35/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9992 - loss: 0.0074 - val_accuracy: 0.9992 - val_loss: 0.0067
# Epoch 36/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0084 - val_accuracy: 0.9975 - val_loss: 0.0141
# Epoch 37/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9992 - loss: 0.0118 - val_accuracy: 0.9975 - val_loss: 0.0165
# Epoch 38/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0086 - val_accuracy: 0.9975 - val_loss: 0.0185
# Epoch 39/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0083 - val_accuracy: 0.9975 - val_loss: 0.0200
# Epoch 40/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0072 - val_accuracy: 0.9975 - val_loss: 0.0217
# Epoch 41/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0080 - val_accuracy: 0.9975 - val_loss: 0.0227
# Epoch 42/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0078 - val_accuracy: 0.9975 - val_loss: 0.0248
# Epoch 43/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0072 - val_accuracy: 0.9975 - val_loss: 0.0262
# Epoch 44/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0069 - val_accuracy: 0.9975 - val_loss: 0.0273
# Epoch 45/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0075 - val_accuracy: 0.9975 - val_loss: 0.0289
# Epoch 46/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0073 - val_accuracy: 0.9975 - val_loss: 0.0287
# Epoch 47/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0083 - val_accuracy: 0.9975 - val_loss: 0.0278
# Epoch 48/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0100 - val_accuracy: 0.9975 - val_loss: 0.0283
# Epoch 49/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0082 - val_accuracy: 0.9967 - val_loss: 0.0297
# Epoch 50/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0074 - val_accuracy: 0.9967 - val_loss: 0.0311
# Epoch 51/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9992 - loss: 0.0105 - val_accuracy: 0.9967 - val_loss: 0.0321
# Epoch 52/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9990 - loss: 0.0089 - val_accuracy: 0.9967 - val_loss: 0.0308
# Epoch 53/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9992 - loss: 0.0099 - val_accuracy: 0.9967 - val_loss: 0.0322
# Epoch 54/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9992 - loss: 0.0072 - val_accuracy: 0.9967 - val_loss: 0.0325
# Epoch 55/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0081 - val_accuracy: 0.9967 - val_loss: 0.0331
# Epoch 56/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0072 - val_accuracy: 0.9967 - val_loss: 0.0337
# Epoch 57/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 112ms/step - accuracy: 0.9992 - loss: 0.0075 - val_accuracy: 0.9967 - val_loss: 0.0348
# Epoch 58/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 112ms/step - accuracy: 0.9992 - loss: 0.0101 - val_accuracy: 0.9967 - val_loss: 0.0357
# Epoch 59/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.9992 - loss: 0.0081 - val_accuracy: 0.9967 - val_loss: 0.0366
# Epoch 60/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.9992 - loss: 0.0065 - val_accuracy: 0.9967 - val_loss: 0.0364
# Epoch 61/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 112ms/step - accuracy: 0.9992 - loss: 0.0057 - val_accuracy: 0.9967 - val_loss: 0.0364
# Epoch 62/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.9992 - loss: 0.0068 - val_accuracy: 0.9967 - val_loss: 0.0368
# Epoch 63/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 8s 112ms/step - accuracy: 0.9992 - loss: 0.0081 - val_accuracy: 0.9967 - val_loss: 0.0378
# Epoch 64/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0066 - val_accuracy: 0.9967 - val_loss: 0.0382
# Epoch 65/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 112ms/step - accuracy: 0.9992 - loss: 0.0063 - val_accuracy: 0.9967 - val_loss: 0.0376
# Epoch 66/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0087 - val_accuracy: 0.9967 - val_loss: 0.0380
# Epoch 67/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0081 - val_accuracy: 0.9975 - val_loss: 0.0377
# Epoch 68/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 115ms/step - accuracy: 0.9992 - loss: 0.0067 - val_accuracy: 0.9975 - val_loss: 0.0373
# Epoch 69/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9985 - loss: 0.0092 - val_accuracy: 0.9975 - val_loss: 0.0363
# Epoch 70/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0094 - val_accuracy: 0.9975 - val_loss: 0.0374
# Epoch 71/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0065 - val_accuracy: 0.9975 - val_loss: 0.0375
# Epoch 72/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9992 - loss: 0.0090 - val_accuracy: 0.9975 - val_loss: 0.0380
# Epoch 73/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0065 - val_accuracy: 0.9975 - val_loss: 0.0379
# Epoch 74/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0071 - val_accuracy: 0.9975 - val_loss: 0.0380
# Epoch 75/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9992 - loss: 0.0083 - val_accuracy: 0.9975 - val_loss: 0.0385
# Epoch 76/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0065 - val_accuracy: 0.9975 - val_loss: 0.0385
# Epoch 77/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0068 - val_accuracy: 0.9975 - val_loss: 0.0387
# Epoch 78/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9992 - loss: 0.0081 - val_accuracy: 0.9975 - val_loss: 0.0387
# Epoch 79/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9992 - loss: 0.0074 - val_accuracy: 0.9975 - val_loss: 0.0385
# Epoch 80/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0064 - val_accuracy: 0.9975 - val_loss: 0.0391
# Epoch 81/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0061 - val_accuracy: 0.9975 - val_loss: 0.0390
# Epoch 82/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0083 - val_accuracy: 0.9975 - val_loss: 0.0404
# Epoch 83/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0080 - val_accuracy: 0.9975 - val_loss: 0.0412
# Epoch 84/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9992 - loss: 0.0106 - val_accuracy: 0.9975 - val_loss: 0.0419
# Epoch 85/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0088 - val_accuracy: 0.9975 - val_loss: 0.0410
# Epoch 86/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0071 - val_accuracy: 0.9975 - val_loss: 0.0403
# Epoch 87/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0077 - val_accuracy: 0.9975 - val_loss: 0.0405
# Epoch 88/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0070 - val_accuracy: 0.9975 - val_loss: 0.0411
# Epoch 89/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0068 - val_accuracy: 0.9975 - val_loss: 0.0407
# Epoch 90/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 114ms/step - accuracy: 0.9992 - loss: 0.0086 - val_accuracy: 0.9975 - val_loss: 0.0415
# Epoch 91/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0084 - val_accuracy: 0.9975 - val_loss: 0.0427
# Epoch 92/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 112ms/step - accuracy: 0.9992 - loss: 0.0068 - val_accuracy: 0.9975 - val_loss: 0.0417
# Epoch 93/100
# 76/76 ━━━━━━━━━━━━━━━━━━━━ 9s 113ms/step - accuracy: 0.9992 - loss: 0.0071 - val_accuracy: 0.9975 - val_loss: 0.0417
# Epoch 93: early stopping
# Restoring model weights from the end of the best epoch: 33.
# 38/38 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        axial     1.0000    1.0000    1.0000       415
#      coronal     0.9977    1.0000    0.9989       435
#     sagittal     1.0000    0.9972    0.9986       360
#
#     accuracy                         0.9992      1210
#    macro avg     0.9992    0.9991    0.9992      1210
# weighted avg     0.9992    0.9992    0.9992      1210
